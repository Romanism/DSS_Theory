# %% [markdown]
# ### 연습문제2
# - MNIST digit image 전체 데이터를 모두 벡터로 변환하여 하나의 NumPy 행렬 [Math Processing Error]X를 만든다.
#
# - 모든 이미지의 조합에 대해 내적으로 유사도를 구해야 한다. 어떻게 구현하는 것이 효율적일까?

# %% [markdown]
# ### 연습문제2-1

# %%
# 데이터 셋
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_digits
digits = load_digits()

# %%
X = digits.images
X = X.reshape(1, 115008)
# 데이터를 (1,115008)의 벡터형태로 변환했다.

# %% [markdown]
# ### 연습문제 2-2
#
# 내적 유사도를 구하기
#
# - A: (1797 X 64)행렬 - 각 행은 변수, 각 열은 변수에 해당하는 데이터
# - B: (64 X 1797)행렬 - 위의 행렬을 전치행렬로 변환
# - AXB행렬(1797 X 1797)행렬 - 각 변수별로 곱해진 스칼라들이 모여 1797 X 1797행렬을 만들것으로 예상, 이 행렬은 정방행렬이 될 것으로 예상

# %% [markdown]
# ### 연습문제 4
#
# - 위에서 만든 MNIST digit image 전체 데이터 행렬 [Math Processing Error]X와 행렬 곱셈을 이용하여 모든 이미지의 조합에 대한 유사도를 구한다. 이 결과는 이미지의 데이터의 갯수를 크기로 하는 정방행렬이 된다.
# - 유사도 정방행렬을 이미지로 시각화 한다

# %% [markdown]
# ### 연습문제 4-1

# %%
v = X.reshape(1797, 64)
np.dot(v, v.T)
# Out:
# array([[ 3070.,  1866.,  2264., ...,  2812.,  3006.,  2898.],
#        [ 1866.,  4209.,  3432., ...,  3906.,  3083.,  3307.],
#        [ 2264.,  3432.,  4388., ...,  4005.,  3063.,  3697.],
#        ...,
#        [ 2812.,  3906.,  4005., ...,  5092.,  3729.,  4598.],
#        [ 3006.,  3083.,  3063., ...,  3729.,  4316.,  3850.],
#        [ 2898.,  3307.,  3697., ...,  4598.,  3850.,  4938.]])

# %% [markdown]
# ### 연습문제 4-2

# %%
# %matplotlib inline
f, ax = plt.subplots(1, 1)
ax.imshow(np.dot(v, v.T), interpolation='nearest', cmap=plt.cm.bone_r)
ax.grid(False)
plt.tight_layout()
plt.show()

# %%
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces()

f, ax = plt.subplots(1, 3)
ax[0].imshow(faces.images[0])
ax[0].grid(False)
ax[0].set_title("x1")

ax[1].imshow(faces.images[10])
ax[1].grid(False)
ax[1].set_title("x2")

ax[2].imshow(0.6 * faces.images[0] + 0.4 * faces.images[10])
ax[2].grid(False)
ax[2].set_title("0.6x1 + 0.4x2")

plt.show()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\Rome\scikit_learn_data
